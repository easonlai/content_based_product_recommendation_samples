# %% [markdown]
# # Azure Text Analytics (Key Phase Extraction) Demo

# %% [markdown]
# Import necessary libraries

# %%
from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential
import pandas as pd

# %% [markdown]
# Define subscription endpoint and key

# %%
key = "PLEASE-ENTER-YOUR-OWN-KEY"
endpoint = "https://PLEASE-ENTER-YOUR-OWN-ENDPOINT.cognitiveservices.azure.com/"

# %% [markdown]
# Authenticate the client

# %%
def authenticate_client():
    ta_credential = AzureKeyCredential(key)
    text_analytics_client = TextAnalyticsClient(
            endpoint=endpoint, 
            credential=ta_credential)
    return text_analytics_client

client = authenticate_client()

# %% [markdown]
# Key phrase extraction

# %%
def key_phrase_extraction_example(client):

    try:
        documents = [
                     "Japan Origin. Combat hair breakage with Dove Japan Hair Breakage Protection range and bring back a head of silky hair stronger and smoother."
                    ]

        response = client.extract_key_phrases(documents = documents)[0]

        if not response.is_error:
            print("\tKey Phrases:")
            for phrase in response.key_phrases:
                print("\t\t", phrase)
        else:
            print(response.id, response.error)

    except Exception as err:
        print("Encountered exception. {}".format(err))
        
key_phrase_extraction_example(client)
# Out:
# 	Key Phrases:
# 		 Dove Japan Hair Breakage Protection range
# 		 Combat hair breakage
# 		 Japan Origin
# 		 silky hair
# 		 head

# %%
# Load the source dataset.
df = pd.read_csv('.\data\data_v2.csv')

# %%
df.head()
# Out:
#    Product_ID Product_Category Brand_Name  \
# 0      100001          SHAMPOO       DOVE
# 1      100002          SHAMPOO       DOVE
# 2      100003          SHAMPOO       DOVE
# 3      100004          SHAMPOO       DOVE
# 4      100005          SHAMPOO       DOVE
#
#                               Product_Name  \
# 0    DOVE BOTANIC BREAKAGE PROTECT SHAMPOO
# 1  DOVE BOTANIC SPLIT ENDS PROTECT SHAMPOO
# 2            DOVE LIGHT MOIST PURE SHAMPOO
# 3         DOVE JAPAN AIRY MOISTURE SHAMPOO
# 4         DOVE JAPAN RICH MOISTURE SHAMPOO
#
#                                      Product_Details Origin  \
# 0  Japan Origin. Combat hair breakage with Dove J...  Japan
# 1  Japan Origin. Looking for smooth and straight ...  Japan
# 2  China Origin. Dove Light Moisture & Purifying ...  China
# 3  Japan Origin. Featuring Oxygen 1 that attracts...  Japan
# 4  Japan Origin. Dove’s unique advanced moisture ...  Japan
#
#                                          Ingredients
# 0  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
# 1  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
# 2  Ingredients: Water  Sodium Laureth Sulfate  So...
# 3  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
# 4  Water  Sodium Laureth Sulfate  Cocamidopropyl ...

# %%
# Configure Azure Text Analytics client library.
ta_credential = AzureKeyCredential(key)
text_analytics_client = TextAnalyticsClient(
        endpoint=endpoint, 
        credential=ta_credential)
client = text_analytics_client

main_df = []
key_phrase_extract = []

# Pass Product Details text content to Azure Text Analytics and collect key phases extraction result.
for index, headers in df.iterrows():
    Product_ID = str(headers['Product_ID'])
    Product_Category = str(headers['Product_Category'])
    Brand_Name = str(headers['Brand_Name'])
    Product_Name = str(headers['Product_Name'])
    Origin = str(headers['Origin'])
    Ingredients =  str(headers['Ingredients'])
    product_details_text_content = str(headers['Product_Details'])
    print("Product Details Text Content: {}".format(product_details_text_content))
    documents = [product_details_text_content]
    response_ekp = client.extract_key_phrases(documents = documents)[0]
    for phrase in response_ekp.key_phrases:
                #print("Key phrase: {}".format(phrase))
                key_phrase_extract.append(phrase)
                print(key_phrase_extract)
    
    main_df.append([Product_ID, Product_Category, Brand_Name, Product_Name, product_details_text_content, Origin, 
                                        Ingredients, key_phrase_extract])
    
    key_phrase_extract = []

# Convert collected post text content with sentiment to Pandas dataframes.
main_df = pd.DataFrame(main_df, columns=['Product_ID','Product_Category',
                               'Brand_Name','Product_Name','Product_Details',
                               'Origin','Ingredients','key_phrase_extract'])
# Out:
# Product Details Text Content: Japan Origin. Combat hair breakage with Dove Japan Hair Breakage Protection range and bring back a head of silky hair  stronger and smoother.
#
# ['Dove Japan Hair Breakage Protection range']
# ['Dove Japan Hair Breakage Protection range', 'Combat hair breakage']
# ['Dove Japan Hair Breakage Protection range', 'Combat hair breakage', 'Japan Origin']
# ['Dove Japan Hair Breakage Protection range', 'Combat hair breakage', 'Japan Origin', 'silky hair']
# ['Dove Japan Hair Breakage Protection range', 'Combat hair breakage', 'Japan Origin', 'silky hair', 'head']
# Product Details Text Content: Japan Origin. Looking for smooth and straight hair that is easy to look after  Dove Japan Straight and Split Ends Protection range is designed for frizzy  hair knot and split ends hair type  leave your hair smooth and shiny silkness.
# ['Split Ends Protection range']
# ['Split Ends Protection range', 'Dove Japan Straight']
# ['Split Ends Protection range', 'Dove Japan Straight', 'frizzy  hair knot']
# ['Split Ends Protection range', 'Dove Japan Straight', 'frizzy  hair knot', 'Japan Origin']
# ['Split Ends Protection range', 'Dove Japan Straight', 'frizzy  hair knot', 'Japan Origin', 'straight hair']
# ['Split Ends Protection range', 'Dove Japan Straight', 'frizzy  hair knot', 'Japan Origin', 'straight hair', 'hair type']
# ['Split Ends Protection range', 'Dove Japan Straight', 'frizzy  hair knot', 'Japan Origin', 'straight hair', 'hair type', 'shiny silkness']
# ['Split Ends Protection range', 'Dove Japan Straight', 'frizzy  hair knot', 'Japan Origin', 'straight hair', 'hair type', 'shiny silkness', 'smooth']
# Product Details Text Content: China Origin. Dove Light Moisture & Purifying range  infused with natural sourced lotus extract  replenish essential nutrients. From the 1st use  it keeps hair smooth.
# ['natural sourced lotus extract']
# ['natural sourced lotus extract', 'Dove Light Moisture']
# ['natural sourced lotus extract', 'Dove Light Moisture', 'China Origin']
# ['natural sourced lotus extract', 'Dove Light Moisture', 'China Origin', 'Purifying range']
# ['natural sourced lotus extract', 'Dove Light Moisture', 'China Origin', 'Purifying range', 'essential nutrients']
# ['natural sourced lotus extract', 'Dove Light Moisture', 'China Origin', 'Purifying range', 'essential nutrients', '1st use']
# ['natural sourced lotus extract', 'Dove Light Moisture', 'China Origin', 'Purifying range', 'essential nutrients', '1st use', 'hair']
# Product Details Text Content: Japan Origin. Featuring Oxygen 1 that attracts moisture.
# Advanced Moisture Oxygen formula unique to Dove  infused with oxygen-combined smooth moisture ingredient 2.
#  1 Oxygen atom in the ingredient structure  2 Cation Guargum
# Transparent shampoo washes your hair soft and fresh  preparing your hair for the next step of care after shampoo.
#
# Subtle burst of elegant floral and fresh fruits.
#
# Even the dry  spread and frizzy hair becomes this manageable.
# Airy finish that is so lightly smooth and manageable.
# ['oxygen-combined smooth moisture ingredient']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom', 'Japan Origin']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom', 'Japan Origin', '2 Cation Guargum']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom', 'Japan Origin', '2 Cation Guargum', 'next step']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom', 'Japan Origin', '2 Cation Guargum', 'next step', 'Subtle burst']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom', 'Japan Origin', '2 Cation Guargum', 'next step', 'Subtle burst', 'elegant floral']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom', 'Japan Origin', '2 Cation Guargum', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom', 'Japan Origin', '2 Cation Guargum', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom', 'Japan Origin', '2 Cation Guargum', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Airy finish']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom', 'Japan Origin', '2 Cation Guargum', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Airy finish', 'Transparent shampoo']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom', 'Japan Origin', '2 Cation Guargum', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Airy finish', 'Transparent shampoo', 'frizzy hair']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom', 'Japan Origin', '2 Cation Guargum', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Airy finish', 'Transparent shampoo', 'frizzy hair', 'Dove']
# ['oxygen-combined smooth moisture ingredient', 'Advanced Moisture Oxygen formula', 'ingredient structure', '1 Oxygen atom', 'Japan Origin', '2 Cation Guargum', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Airy finish', 'Transparent shampoo', 'frizzy hair', 'Dove', 'care']
# Product Details Text Content: Japan Origin. Dove’s unique advanced moisture oil formula  infused with moisture lipid  1 which is same as the component that naturally exists in hair.
# Infused with moisture lipid that penetrates into the hair and Squalane 2 which cares for the surface of the hair.
#  1 Oleic acid: moisture ingredient   2 Moisture ingredient
# Transparent shampoo washes your hair soft and fresh  preparing your hair for the next step of care after shampoo.
#
# Subtle burst of elegant floral and fresh fruits.
#
# Even the dry  spread and frizzy hair becomes this manageable.
# Rich finish that is soft and manageable.
# ['unique advanced moisture oil formula']
# ['unique advanced moisture oil formula', 'moisture lipid']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step', 'Subtle burst']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step', 'Subtle burst', 'elegant floral']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Rich finish']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Rich finish', 'Transparent shampoo']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Rich finish', 'Transparent shampoo', 'frizzy hair']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Rich finish', 'Transparent shampoo', 'frizzy hair', 'Dove']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Rich finish', 'Transparent shampoo', 'frizzy hair', 'Dove', 'component']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Rich finish', 'Transparent shampoo', 'frizzy hair', 'Dove', 'component', 'Squalane']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Rich finish', 'Transparent shampoo', 'frizzy hair', 'Dove', 'component', 'Squalane', 'surface']
# ['unique advanced moisture oil formula', 'moisture lipid', 'moisture ingredient', 'Japan Origin', '1 Oleic acid', 'next step', 'Subtle burst', 'elegant floral', 'fresh fruits', 'dry  spread', 'Rich finish', 'Transparent shampoo', 'frizzy hair', 'Dove', 'component', 'Squalane', 'surface', 'care']
# Product Details Text Content: Thailand Origin. With Pro-Moisture Complex  leaves hair straighter & manageable
# ['Thailand Origin']
# ['Thailand Origin', 'Pro-Moisture Complex']
# ['Thailand Origin', 'Pro-Moisture Complex', 'straighter']
# Product Details Text Content: China Origin. Contains PPT can protect dry hair  moisturizing ingredients can clean and fully penetrate dry  fragile hair.
# ['dry hair  moisturizing ingredients']
# ['dry hair  moisturizing ingredients', 'dry  fragile hair']
# ['dry hair  moisturizing ingredients', 'dry  fragile hair', 'China Origin']
# ['dry hair  moisturizing ingredients', 'dry  fragile hair', 'China Origin', 'Contains']
# ['dry hair  moisturizing ingredients', 'dry  fragile hair', 'China Origin', 'Contains', 'PPT']
# Product Details Text Content: China Origin. Contains PPT can protect dry hair  moisturizing ingredients can clean and fully penetrate dry  fragile hair.
# ['dry hair  moisturizing ingredients']
# ['dry hair  moisturizing ingredients', 'dry  fragile hair']
# ['dry hair  moisturizing ingredients', 'dry  fragile hair', 'China Origin']
# ['dry hair  moisturizing ingredients', 'dry  fragile hair', 'China Origin', 'Contains']
# ['dry hair  moisturizing ingredients', 'dry  fragile hair', 'China Origin', 'Contains', 'PPT']
# Product Details Text Content: China Origin. Light texture moisturizing formula makes hair feeling light and smooth and can with any hair style .
# ['Light texture moisturizing formula']
# ['Light texture moisturizing formula', 'China Origin']
# ['Light texture moisturizing formula', 'China Origin', 'hair style']
# Product Details Text Content: China Origin. Contains PPT can protect dry hair  moisturizing ingredients can clean and fully penetrate dry  fragile hair.
# ['dry hair  moisturizing ingredients']
# ['dry hair  moisturizing ingredients', 'dry  fragile hair']
# ['dry hair  moisturizing ingredients', 'dry  fragile hair', 'China Origin']
# ['dry hair  moisturizing ingredients', 'dry  fragile hair', 'China Origin', 'Contains']
# ['dry hair  moisturizing ingredients', 'dry  fragile hair', 'China Origin', 'Contains', 'PPT']
# Product Details Text Content: China Origin. Rejoice Innovative Hair make-up removal!
# 1. Inspired by French  Micellar Water Hair Make-up technology  mild to the skin
# 2. Micellar micron particle easily get into the scalp pore  the clean the grease hidden in the deep pore
# 3. Natural white tea and water lily essence. Purify and Moisturizing  deliver volume up smoothness.
# Intensively deep cleansing the excessive oil. Retain scalp and hair oil & water balance  long time control oil. Hair root is fresh and without stickiness  hair end not dry. Hair can keep moisture and smooth always.
#
# Means not adding silicone  applies to shampoo products only.
# ['Long-lasting oil control formula']
# ['Long-lasting oil control formula', 'long time control oil']
# ['Long-lasting oil control formula', 'long time control oil', '4times water lock']
# ['Long-lasting oil control formula', 'long time control oil', '4times water lock', 'excessive oil']
# ['Long-lasting oil control formula', 'long time control oil', '4times water lock', 'excessive oil', 'hair oil']
# ['Long-lasting oil control formula', 'long time control oil', '4times water lock', 'excessive oil', 'hair oil', 'Taiwan Origin']
# ['Long-lasting oil control formula', 'long time control oil', '4times water lock', 'excessive oil', 'hair oil', 'Taiwan Origin', 'natural repair']
# ['Long-lasting oil control formula', 'long time control oil', '4times water lock', 'excessive oil', 'hair oil', 'Taiwan Origin', 'natural repair', 'shampoo products']
# ['Long-lasting oil control formula', 'long time control oil', '4times water lock', 'excessive oil', 'hair oil', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Hair root']
# ['Long-lasting oil control formula', 'long time control oil', '4times water lock', 'excessive oil', 'hair oil', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Hair root', 'Watery 0% silicone']
# ['Long-lasting oil control formula', 'long time control oil', '4times water lock', 'excessive oil', 'hair oil', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Hair root', 'Watery 0% silicone', 'hair moisture']
# ['Long-lasting oil control formula', 'long time control oil', '4times water lock', 'excessive oil', 'hair oil', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Hair root', 'Watery 0% silicone', 'hair moisture', 'scalp']
# ['Long-lasting oil control formula', 'long time control oil', '4times water lock', 'excessive oil', 'hair oil', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Hair root', 'Watery 0% silicone', 'hair moisture', 'scalp', 'stickiness']
# ['Long-lasting oil control formula', 'long time control oil', '4times water lock', 'excessive oil', 'hair oil', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Hair root', 'Watery 0% silicone', 'hair moisture', 'scalp', 'stickiness', 'Means']
# Product Details Text Content: Taiwan Origin. Watery 0% silicone  protect hair moisture
# 4times water lock & natural repair
#
# Quick Dry Airy formula
# Effective to reduce tangled hair and also add airy feeling to hair. No flat hair top  while hair tip does not tangle. Hair become distinctly seperated  when hair dryer lightly blow  air pass through hair  make hair easy to dry  save 20%# of the hair blowing time  and protect hair from heat and friction.
#
# Means not adding silicone  applies to shampoo products only
# ['Quick Dry Airy formula']
# ['Quick Dry Airy formula', '4times water lock']
# ['Quick Dry Airy formula', '4times water lock', 'flat hair top']
# ['Quick Dry Airy formula', '4times water lock', 'flat hair top', 'airy feeling']
# ['Quick Dry Airy formula', '4times water lock', 'flat hair top', 'airy feeling', 'Taiwan Origin']
# ['Quick Dry Airy formula', '4times water lock', 'flat hair top', 'airy feeling', 'Taiwan Origin', 'natural repair']
# ['Quick Dry Airy formula', '4times water lock', 'flat hair top', 'airy feeling', 'Taiwan Origin', 'natural repair', 'shampoo products']
# ['Quick Dry Airy formula', '4times water lock', 'flat hair top', 'airy feeling', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Watery 0% silicone']
# ['Quick Dry Airy formula', '4times water lock', 'flat hair top', 'airy feeling', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Watery 0% silicone', 'hair moisture']
# ['Quick Dry Airy formula', '4times water lock', 'flat hair top', 'airy feeling', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Watery 0% silicone', 'hair moisture', 'tangled hair']
# ['Quick Dry Airy formula', '4times water lock', 'flat hair top', 'airy feeling', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Watery 0% silicone', 'hair moisture', 'tangled hair', 'hair tip']
# ['Quick Dry Airy formula', '4times water lock', 'flat hair top', 'airy feeling', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Watery 0% silicone', 'hair moisture', 'tangled hair', 'hair tip', 'heat']
# ['Quick Dry Airy formula', '4times water lock', 'flat hair top', 'airy feeling', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Watery 0% silicone', 'hair moisture', 'tangled hair', 'hair tip', 'heat', 'friction']
# ['Quick Dry Airy formula', '4times water lock', 'flat hair top', 'airy feeling', 'Taiwan Origin', 'natural repair', 'shampoo products', 'Watery 0% silicone', 'hair moisture', 'tangled hair', 'hair tip', 'heat', 'friction', 'Means']
# Product Details Text Content: Taiwan Origin. Watery 0% silicone  protect hair moisture
# 4times water lock & natural repair
#
# Highly effective lock moisture anti-dandruff formulation
# Contains Piroctone Olamine which is an active anti-dandruff ingredient that effectively remove dandruff  prevent itchy. After use  scalp can keep refresh and moisturized  no more dandruff problem.
#
# Means not adding silicone  applies to shampoo products only
# ['effective lock moisture anti-dandruff formulation']
# ['effective lock moisture anti-dandruff formulation', '4times water lock']
# ['effective lock moisture anti-dandruff formulation', '4times water lock', 'active anti-dandruff ingredient']
# ['effective lock moisture anti-dandruff formulation', '4times water lock', 'active anti-dandruff ingredient', 'hair moisture']
# ['effective lock moisture anti-dandruff formulation', '4times water lock', 'active anti-dandruff ingredient', 'hair moisture', 'Taiwan Origin']
# ['effective lock moisture anti-dandruff formulation', '4times water lock', 'active anti-dandruff ingredient', 'hair moisture', 'Taiwan Origin', 'natural repair']
# ['effective lock moisture anti-dandruff formulation', '4times water lock', 'active anti-dandruff ingredient', 'hair moisture', 'Taiwan Origin', 'natural repair', 'Piroctone Olamine']
# ['effective lock moisture anti-dandruff formulation', '4times water lock', 'active anti-dandruff ingredient', 'hair moisture', 'Taiwan Origin', 'natural repair', 'Piroctone Olamine', 'shampoo products']
# ['effective lock moisture anti-dandruff formulation', '4times water lock', 'active anti-dandruff ingredient', 'hair moisture', 'Taiwan Origin', 'natural repair', 'Piroctone Olamine', 'shampoo products', 'Watery 0% silicone']
# ['effective lock moisture anti-dandruff formulation', '4times water lock', 'active anti-dandruff ingredient', 'hair moisture', 'Taiwan Origin', 'natural repair', 'Piroctone Olamine', 'shampoo products', 'Watery 0% silicone', 'dandruff problem']
# ['effective lock moisture anti-dandruff formulation', '4times water lock', 'active anti-dandruff ingredient', 'hair moisture', 'Taiwan Origin', 'natural repair', 'Piroctone Olamine', 'shampoo products', 'Watery 0% silicone', 'dandruff problem', 'itchy']
# ['effective lock moisture anti-dandruff formulation', '4times water lock', 'active anti-dandruff ingredient', 'hair moisture', 'Taiwan Origin', 'natural repair', 'Piroctone Olamine', 'shampoo products', 'Watery 0% silicone', 'dandruff problem', 'itchy', 'scalp']
# ['effective lock moisture anti-dandruff formulation', '4times water lock', 'active anti-dandruff ingredient', 'hair moisture', 'Taiwan Origin', 'natural repair', 'Piroctone Olamine', 'shampoo products', 'Watery 0% silicone', 'dandruff problem', 'itchy', 'scalp', 'Means']

# %%
main_df.head()
# Out:
#   Product_ID Product_Category Brand_Name  \
# 0     100001          SHAMPOO       DOVE
# 1     100002          SHAMPOO       DOVE
# 2     100003          SHAMPOO       DOVE
# 3     100004          SHAMPOO       DOVE
# 4     100005          SHAMPOO       DOVE
#
#                               Product_Name  \
# 0    DOVE BOTANIC BREAKAGE PROTECT SHAMPOO
# 1  DOVE BOTANIC SPLIT ENDS PROTECT SHAMPOO
# 2            DOVE LIGHT MOIST PURE SHAMPOO
# 3         DOVE JAPAN AIRY MOISTURE SHAMPOO
# 4         DOVE JAPAN RICH MOISTURE SHAMPOO
#
#                                      Product_Details Origin  \
# 0  Japan Origin. Combat hair breakage with Dove J...  Japan
# 1  Japan Origin. Looking for smooth and straight ...  Japan
# 2  China Origin. Dove Light Moisture & Purifying ...  China
# 3  Japan Origin. Featuring Oxygen 1 that attracts...  Japan
# 4  Japan Origin. Dove’s unique advanced moisture ...  Japan
#
#                                          Ingredients  \
# 0  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
# 1  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
# 2  Ingredients: Water  Sodium Laureth Sulfate  So...
# 3  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
# 4  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
#
#                                   key_phrase_extract
# 0  [Dove Japan Hair Breakage Protection range, Co...
# 1  [Split Ends Protection range, Dove Japan Strai...
# 2  [natural sourced lotus extract, Dove Light Moi...
# 3  [oxygen-combined smooth moisture ingredient, A...
# 4  [unique advanced moisture oil formula, moistur...

# %%
main_df.to_csv('.\data\data_v3a.csv', index=False)

# %%
# Load the source dataset.
df = pd.read_csv('.\data\data_v3a.csv')

# %%
df.head()
# Out:
#    Product_ID Product_Category Brand_Name  \
# 0      100001          SHAMPOO       DOVE
# 1      100002          SHAMPOO       DOVE
# 2      100003          SHAMPOO       DOVE
# 3      100004          SHAMPOO       DOVE
# 4      100005          SHAMPOO       DOVE
#
#                               Product_Name  \
# 0    DOVE BOTANIC BREAKAGE PROTECT SHAMPOO
# 1  DOVE BOTANIC SPLIT ENDS PROTECT SHAMPOO
# 2            DOVE LIGHT MOIST PURE SHAMPOO
# 3         DOVE JAPAN AIRY MOISTURE SHAMPOO
# 4         DOVE JAPAN RICH MOISTURE SHAMPOO
#
#                                      Product_Details Origin  \
# 0  Japan Origin. Combat hair breakage with Dove J...  Japan
# 1  Japan Origin. Looking for smooth and straight ...  Japan
# 2  China Origin. Dove Light Moisture & Purifying ...  China
# 3  Japan Origin. Featuring Oxygen 1 that attracts...  Japan
# 4  Japan Origin. Dove’s unique advanced moisture ...  Japan
#
#                                          Ingredients  \
# 0  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
# 1  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
# 2  Ingredients: Water  Sodium Laureth Sulfate  So...
# 3  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
# 4  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
#
#                                   key_phrase_extract
# 0  ['Dove Japan Hair Breakage Protection range', ...
# 1  ['Split Ends Protection range', 'Dove Japan St...
# 2  ['natural sourced lotus extract', 'Dove Light ...
# 3  ['oxygen-combined smooth moisture ingredient',...
# 4  ['unique advanced moisture oil formula', 'mois...

# %%
df['key_phrase_extract'] = df['key_phrase_extract'].str.replace(',',' ')
df['key_phrase_extract'] = df['key_phrase_extract'].str.replace('[','')
df['key_phrase_extract'] = df['key_phrase_extract'].str.replace(']','')
df['key_phrase_extract'] = df['key_phrase_extract'].str.replace('\'','')
# Out:
# C:\Users\easonlai\AppData\Local\Temp/ipykernel_30456/2915575872.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['key_phrase_extract'] = df['key_phrase_extract'].str.replace('[','')
# C:\Users\easonlai\AppData\Local\Temp/ipykernel_30456/2915575872.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['key_phrase_extract'] = df['key_phrase_extract'].str.replace(']','')

# %%
df.head()
# Out:
#    Product_ID Product_Category Brand_Name  \
# 0      100001          SHAMPOO       DOVE
# 1      100002          SHAMPOO       DOVE
# 2      100003          SHAMPOO       DOVE
# 3      100004          SHAMPOO       DOVE
# 4      100005          SHAMPOO       DOVE
#
#                               Product_Name  \
# 0    DOVE BOTANIC BREAKAGE PROTECT SHAMPOO
# 1  DOVE BOTANIC SPLIT ENDS PROTECT SHAMPOO
# 2            DOVE LIGHT MOIST PURE SHAMPOO
# 3         DOVE JAPAN AIRY MOISTURE SHAMPOO
# 4         DOVE JAPAN RICH MOISTURE SHAMPOO
#
#                                      Product_Details Origin  \
# 0  Japan Origin. Combat hair breakage with Dove J...  Japan
# 1  Japan Origin. Looking for smooth and straight ...  Japan
# 2  China Origin. Dove Light Moisture & Purifying ...  China
# 3  Japan Origin. Featuring Oxygen 1 that attracts...  Japan
# 4  Japan Origin. Dove’s unique advanced moisture ...  Japan
#
#                                          Ingredients  \
# 0  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
# 1  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
# 2  Ingredients: Water  Sodium Laureth Sulfate  So...
# 3  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
# 4  Water  Sodium Laureth Sulfate  Cocamidopropyl ...
#
#                                   key_phrase_extract
# 0  Dove Japan Hair Breakage Protection range  Com...
# 1  Split Ends Protection range  Dove Japan Straig...
# 2  natural sourced lotus extract  Dove Light Mois...
# 3  oxygen-combined smooth moisture ingredient  Ad...
# 4  unique advanced moisture oil formula  moisture...

# %%
df.to_csv('.\data\data_v3b.csv', index=False)
